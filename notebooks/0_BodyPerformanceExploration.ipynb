# %% [markdown]
# ## Fitness data trends
#
# data from Kaggle https://www.kaggle.com/datasets/kukuroo3/body-performance-data

# %% [markdown]
# Inspiration <br />
# Which new insights can we extract to reinvent our lifestyles and optimize our individual wellbeing? <br />
# What are the strongest correlations between the various dimensions? <br />
# What are the best predictors of a balanced life? <br />

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Running cells with '/bin/python3' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('../data/bodyPerformance.csv')
df.head()
# Out:
# Running cells with 'base' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n base ipykernel --update-deps --force-reinstall'

# %%
df.shape
# Out:
# (96, 7)

# %%
from explore_fit import quick_profiler as qp

# %%
qp.details(df)
# Out:
#    Row count  Column count  Data volume (Mb)  Record level volume (kb)
# 0      15972            24              6.28                       0.4

# %%
qp.column_details(df)
# Out:
#                         Data types  Sample Row  Total records   Null values  \
# Timestamp                    object     7/7/15           15972            0
# FRUITS_VEGGIES                int64          3           15972            0
# DAILY_STRESS                 object          2           15972            0
# PLACES_VISITED                int64          2           15972            0
# CORE_CIRCLE                   int64          5           15972            0
# SUPPORTING_OTHERS             int64          0           15972            0
# SOCIAL_NETWORK                int64          5           15972            0
# ACHIEVEMENT                   int64          2           15972            0
# DONATION                      int64          0           15972            0
# BMI_RANGE                     int64          1           15972            0
# TODO_COMPLETED                int64          6           15972            0
# ...
